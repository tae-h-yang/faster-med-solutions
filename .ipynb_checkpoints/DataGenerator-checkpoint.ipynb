# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import date, timedelta
import random
import faker
fake = faker.Faker()

# %%
medicine_names = ["Metformin", "Metoprolol", "Fluticasone", "Ipratropium", "Methotrexate", "Raloxifene", "Atorvastatin", "Carbamazepine", "Azathioprine"]

# %%
my_date = date(2023,9,1) + timedelta(days=1)
str(my_date)
# Out:
# '2023-09-02'

# %%
int(np.random.normal(10,2,size=1))
# Out:
# 9

# %%
class Medicine:
    def __init__(self, name, quantity, reorder_point, reorder_quantity, date):
        self.name = name
        self.quantity = quantity
        self.reorder_point = reorder_point
        self.reorder_quantity = reorder_quantity
        self.date = date

    def increase_quantity(self, amount):
        self.quantity += amount
        self.date = self.date + timedelta(days=1)

    def decrease_quantity(self, amount):
        if self.quantity - amount < 0:
            self.quantity = 0
            self.date = self.date + timedelta(days=1)
        else:
            print(amount)
            self.quantity -= amount
            self.date = self.date + timedelta(days=1)

    def is_below_reorder_point(self):
        return self.quantity < self.reorder_point

    def simulate(self):
        if self.is_below_reorder_point():
            # print(self.name, self.quantity, self.reorder_point)
            self.increase_quantity(self.reorder_quantity)
        else:
            # print("Yes")
            self.decrease_quantity(abs(int(np.random.normal(self.reorder_point,self.reorder_point//2,size=1))))

# %%
medicine = []
for i in range(len(medicine_names)):
    medicine.append(Medicine(medicine_names[i],int(np.random.normal(100,30,size=1)), int(np.random.normal(20,10,size=1)), int(np.random.normal(100,30,size=1)), date(2023,9,1)))

data = []
for i in range(30):
    for j in range(len(medicine)):
        data.append({"Date":str(medicine[j].date), "Medicine": medicine[j].name, "Quantity":medicine[j].quantity})
        medicine[j].simulate()
# Out:
# 14
# 28
# 53
# 15
# 20
# 14
# 29
# 36
# 28
# 0
# 36
# 10
# 18
# 38
# 19
# 27
# 26
# 10
# 24
# 8
# 11
# 15
# 15
# 27
# 33
# 5
# 22
# 12
# 9
# 13
# 19
# 23
# 7
# 15
# 38
# 2
# 39
# 20
# 17
# 28
# 22
# 14
# 7
# 46
# 19
# 35
# 8
# 26
# 16
# 14
# 21
# 15
# 8
# 32
# 21
# 8
# 14
# 16
# 18
# 22
# 6
# 17
# 10
# 9
# 24
# 23
# 8
# 4
# 4
# 20
# 15
# 21
# 27
# 9
# 21
# 7
# 15
# 17
# 7
# 17
# 33
# 10
# 6
# 20
# 16
# 17
# 23
# 3
# 23
# 30
# 23
# 19
# 25
# 11
# 39
# 11
# 20
# 25
# 12
# 19
# 22
# 13
# 11
# 14
# 17
# 4
# 4
# 27
# 10
# 8
# 16
# 12
# 15
# 9
# 12
# 0
# 37
# 5
# 22
# 11
# 6
# 11
# 10
# 22
# 38
# 15
# 19
# 29
# 20
# 5
# 5
# 18
# 14
# 21
# 41
# 11
# 27
# 15
# 15
# 6
# 23
# 32
# 12
# 2
# 21
# 5
# 13
# 7
# 21
# 47
# 8
# 30
# 16
# 12
# 10
# 3
# 33
# 21
# 6
# 21
# 17
# 21
# 12
# 8
# 13
# 10
# 13
# 17
# 13
# 6
# 16
# 22
# 0
# 13
# 33
# 14
# 12
# 6
# 17
# 5
# 24
# 31
# 11
# 8
# 30
# 24
# 13
# 37
# 17
# 18
# 27
# 5
# 49
# 15
# 19
# 3
# 9
# 13
# 10
# 8
# 24
# 19
# 17
# 13
# 6
# 45
# 8
# 49
# 25
# 0
# 31
# 31
# 25

# %%
data[:]
# Out:
# [{'Date': '2023-09-01', 'Medicine': 'Metformin', 'Quantity': 41},
#  {'Date': '2023-09-01', 'Medicine': 'Metoprolol', 'Quantity': 90},
#  {'Date': '2023-09-01', 'Medicine': 'Fluticasone', 'Quantity': 150},
#  {'Date': '2023-09-01', 'Medicine': 'Ipratropium', 'Quantity': 57},
#  {'Date': '2023-09-01', 'Medicine': 'Methotrexate', 'Quantity': 140},
#  {'Date': '2023-09-01', 'Medicine': 'Raloxifene', 'Quantity': 115},
#  {'Date': '2023-09-01', 'Medicine': 'Atorvastatin', 'Quantity': 62},
#  {'Date': '2023-09-01', 'Medicine': 'Carbamazepine', 'Quantity': 127},
#  {'Date': '2023-09-01', 'Medicine': 'Azathioprine', 'Quantity': 53},
#  {'Date': '2023-09-02', 'Medicine': 'Metformin', 'Quantity': 27},
#  {'Date': '2023-09-02', 'Medicine': 'Metoprolol', 'Quantity': 62},
#  {'Date': '2023-09-02', 'Medicine': 'Fluticasone', 'Quantity': 97},
#  {'Date': '2023-09-02', 'Medicine': 'Ipratropium', 'Quantity': 42},
#  {'Date': '2023-09-02', 'Medicine': 'Methotrexate', 'Quantity': 120},
#  {'Date': '2023-09-02', 'Medicine': 'Raloxifene', 'Quantity': 101},
#  {'Date': '2023-09-02', 'Medicine': 'Atorvastatin', 'Quantity': 33},
#  {'Date': '2023-09-02', 'Medicine': 'Carbamazepine', 'Quantity': 91},
#  {'Date': '2023-09-02', 'Medicine': 'Azathioprine', 'Quantity': 25},
#  {'Date': '2023-09-03', 'Medicine': 'Metformin', 'Quantity': 27},
#  {'Date': '2023-09-03', 'Medicine': 'Metoprolol', 'Quantity': 26},
#  {'Date': '2023-09-03', 'Medicine': 'Fluticasone', 'Quantity': 87},
#  {'Date': '2023-09-03', 'Medicine': 'Ipratropium', 'Quantity': 24},
#  {'Date': '2023-09-03', 'Medicine': 'Methotrexate', 'Quantity': 82},
#  {'Date': '2023-09-03', 'Medicine': 'Raloxifene', 'Quantity': 82},
#  {'Date': '2023-09-03', 'Medicine': 'Atorvastatin', 'Quantity': 6},
#  {'Date': '2023-09-03', 'Medicine': 'Carbamazepine', 'Quantity': 65},
#  {'Date': '2023-09-03', 'Medicine': 'Azathioprine', 'Quantity': 80},
#  {'Date': '2023-09-04', 'Medicine': 'Metformin', 'Quantity': 17},
#  {'Date': '2023-09-04', 'Medicine': 'Metoprolol', 'Quantity': 2},
#  {'Date': '2023-09-04', 'Medicine': 'Fluticasone', 'Quantity': 79},
#  {'Date': '2023-09-04', 'Medicine': 'Ipratropium', 'Quantity': 13},
#  {'Date': '2023-09-04', 'Medicine': 'Methotrexate', 'Quantity': 67},
#  {'Date': '2023-09-04', 'Medicine': 'Raloxifene', 'Quantity': 67},
#  {'Date': '2023-09-04', 'Medicine': 'Atorvastatin', 'Quantity': 76},
#  {'Date': '2023-09-04', 'Medicine': 'Carbamazepine', 'Quantity': 38},
#  {'Date': '2023-09-29', 'Medicine': 'Carbamazepine', 'Quantity': 67},
#  {'Date': '2023-09-29', 'Medicine': 'Azathioprine', 'Quantity': 0},
#  {'Date': '2023-09-30', 'Medicine': 'Metformin', 'Quantity': 1},
#  {'Date': '2023-09-30', 'Medicine': 'Metoprolol', 'Quantity': 0},
#  {'Date': '2023-09-30', 'Medicine': 'Fluticasone', 'Quantity': 61},
#  {'Date': '2023-09-30', 'Medicine': 'Ipratropium', 'Quantity': 79},
#  {'Date': '2023-09-30', 'Medicine': 'Methotrexate', 'Quantity': 115},
#  {'Date': '2023-09-30', 'Medicine': 'Raloxifene', 'Quantity': 10},
#  {'Date': '2023-09-30', 'Medicine': 'Atorvastatin', 'Quantity': 32},
#  {'Date': '2023-09-30', 'Medicine': 'Carbamazepine', 'Quantity': 59},
#  {'Date': '2023-09-30', 'Medicine': 'Azathioprine', 'Quantity': 55}]

# %%
df = pd.DataFrame(data = data)
pivot_df = df.pivot(index='Medicine', columns='Date', values='Quantity')

# %%
pivot_df
# Out:
# Date           2023-09-01  2023-09-02  2023-09-03  2023-09-04  2023-09-05  \
# Medicine
# Atorvastatin           62          33           6          76          63
# Azathioprine           53          25          80          47          24
# Carbamazepine         127          91          65          38          19
# Fluticasone           150          97          87          79          57
# Ipratropium            57          42          24          13         117
# Metformin              41          27          27          17          12
# Methotrexate          140         120          82          67          55
# Metoprolol             90          62          26           2          43
# Raloxifene            115         101          82          67          58
#
# Date           2023-09-06  2023-09-07  2023-09-08  2023-09-09  2023-09-10  \
# Medicine
# Atorvastatin           46           0          70          54          30
# Azathioprine           79          44          29           7          62
# Carbamazepine         114          95          74          56          33
# Fluticasone            19          93          67          46          29
# Ipratropium           115          93          77          69          59
# Metformin               5          92          84          76          70
# Methotrexate           16           2         126         112         103
# Metoprolol             28           0          41           9          50
# Raloxifene             38          31          17           0         120
#
# Date           ...  2023-09-21  2023-09-22  2023-09-23  2023-09-24  \
# Medicine       ...
# Atorvastatin   ...          68          61          28           0
# Azathioprine   ...          69          22          77          64
# Carbamazepine  ...          77          56          35          27
# Fluticasone    ...          73          71          55          34
# Ipratropium    ...         112          91          79          62
# Metformin      ...          78          66          58          52
# Methotrexate   ...          87          82          72          51
# Metoprolol     ...           0          41          11          52
# Raloxifene     ...         101          88          85          73
#
# Date           2023-09-25  2023-09-26  2023-09-27  2023-09-28  2023-09-29  \
# Medicine
# Atorvastatin           70          64          34           7          77
# Azathioprine           42          25          80          31           0
# Carbamazepine          11         106          82          77          67
# Fluticasone             0          74          43           6          80
# Ipratropium            45          12         116          99          96
# Metformin              42          42          37          24           9
# Methotrexate           38          24          13         137         128
# Metoprolol             39          26           2          43          24
# Raloxifene             67          55          47          29          16
#
# Date           2023-09-30
# Medicine
# Atorvastatin           32
# Azathioprine           55
# Carbamazepine          59
# Fluticasone            61
# Ipratropium            79
# Metformin               1
# Methotrexate          115
# Metoprolol              0
# Raloxifene             10
#
# [9 rows x 30 columns]

# %%
# Set the 'Medicine' column as the index
df.set_index('Medicine', inplace=True)

# Choose the row you want to plot, e.g., 'Metformin'
row_to_plot = df.loc[medicine_names[0]]

# Plot the selected row
ax = row_to_plot.plot(kind='bar')

# Set labels for the x and y-axis
plt.xlabel('Date')
plt.ylabel('Quantity')

# Set the title of the plot
plt.title('Quantity Over Time')

# Show the plot
plt.show()

# %%
medicine_names = ["Metformin 500mg tablet", "Metformin 850mg tablet", "Metformin 1000mg tablet", "Metoprolol 25mg tablet", "Metoprolol 50mg tablet", "Metoprolol 100mg tablet", "Atorvastatin 10mg tablet", "Atorvastatin 20mg tablet", "Atorvastatin 40mg tablet"]

class Medicine:
    def __init__(self, name, quantity, reorder_point, reorder_quantity, date):
        self.name = name
        self.quantity = quantity
        self.reorder_point = reorder_point
        self.reorder_quantity = reorder_quantity
        self.date = date

    def increase_quantity(self, amount):
        self.quantity += amount
        self.date = self.date + timedelta(days=1)

    def decrease_quantity(self, amount):
        if self.quantity - amount < 0:
            self.quantity = 0
            self.date = self.date + timedelta(days=1)
        else:
            # print(amount)
            self.quantity -= amount
            self.date = self.date + timedelta(days=1)

    def is_below_reorder_point(self):
        return self.quantity < self.reorder_point

    def simulate(self):
        if self.is_below_reorder_point():
            # print(self.name, self.quantity, self.reorder_point)
            self.increase_quantity(self.reorder_quantity)
        else:
            # print("Yes")
            self.decrease_quantity(abs(int(np.random.normal(self.reorder_point,self.reorder_point//2,size=1))))

medicine = []
for i in range(len(medicine_names)):
    medicine.append(Medicine(medicine_names[i],int(np.random.normal(100,30,size=1)), int(np.random.normal(20,10,size=1)), int(np.random.normal(100,30,size=1)), date(2023,9,1)))

data = []
for i in range(30):
    for j in range(len(medicine)):
        data.append({"Date":str(medicine[j].date), "Medicine": medicine[j].name, "Quantity":medicine[j].quantity})
        medicine[j].simulate()

df = pd.DataFrame(data = data)
pivot_df = df.pivot(index='Medicine', columns='Date', values='Quantity')

# %%
pivot_df
# Out:
# Date                      2023-09-01  2023-09-02  2023-09-03  2023-09-04  \
# Medicine
# Atorvastatin 10mg tablet         121         101          93          85
# Atorvastatin 20mg tablet          79          15         121          96
# Atorvastatin 40mg tablet         114         114          86          66
# Metformin 1000mg tablet          109          94          86          74
# Metformin 500mg tablet            95          54          29           4
# Metformin 850mg tablet           129          97          88          77
# Metoprolol 100mg tablet          132         109          83          61
# Metoprolol 25mg tablet           124          91          76          70
# Metoprolol 50mg tablet            73          37          18         165
#
# Date                      2023-09-05  2023-09-06  2023-09-07  2023-09-08  \
# Medicine
# Atorvastatin 10mg tablet          68          57          37          24
# Atorvastatin 20mg tablet          51          40           0         106
# Atorvastatin 40mg tablet          63          54          32          24
# Metformin 1000mg tablet           36           0         167         135
# Metformin 500mg tablet           124          98          57          30
# Metformin 850mg tablet            51          44          16         110
# Metoprolol 100mg tablet           40          39          39           4
# Metoprolol 25mg tablet            41          13          96          66
# Metoprolol 50mg tablet           116         108         105          77
#
# Date                      2023-09-09  2023-09-10  ...  2023-09-21  2023-09-22  \
# Medicine                                          ...
# Atorvastatin 10mg tablet          10          80  ...          16           0
# Atorvastatin 20mg tablet          86          59  ...         104          68
# Atorvastatin 40mg tablet           7         130  ...           3         126
# Metformin 1000mg tablet          118          92  ...          68          50
# Metformin 500mg tablet             0         120  ...           0         120
# Metformin 850mg tablet            91          67  ...          71          70
# Metoprolol 100mg tablet          117          88  ...          14         127
# Metoprolol 25mg tablet            41          14  ...          14          97
# Metoprolol 50mg tablet            28         175  ...         110          45
#
# Date                      2023-09-23  2023-09-24  2023-09-25  2023-09-26  \
# Medicine
# Atorvastatin 10mg tablet          70          58          31           4
# Atorvastatin 20mg tablet          42           9         115          78
# Atorvastatin 40mg tablet          96          80          48          32
# Metformin 1000mg tablet           10         177         153         144
# Metformin 500mg tablet           104          76          47          31
# Metformin 850mg tablet            61          40           7         101
# Metoprolol 100mg tablet           95          88          82          52
# Metoprolol 25mg tablet            64          52          28          11
# Metoprolol 50mg tablet            15         162         138         115
#
# Date                      2023-09-27  2023-09-28  2023-09-29  2023-09-30
# Medicine
# Atorvastatin 10mg tablet          74          60          43          29
# Atorvastatin 20mg tablet          43           7         113          87
# Atorvastatin 40mg tablet          24          15         138         127
# Metformin 1000mg tablet          109          84          40           0
# Metformin 500mg tablet             0         120          88          80
# Metformin 850mg tablet            82          71          47          12
# Metoprolol 100mg tablet           49          21           0         113
# Metoprolol 25mg tablet            94          69          63          43
# Metoprolol 50mg tablet           112          68          51           0
#
# [9 rows x 30 columns]

# %%
date_list = []
for i in range(len(data)):
    if i != 0:
        if data[i-1]["Date"] != data[i]["Date"]:
            date_list.append(data[i]["Date"])    
    else:
        date_list.append(data[i]["Date"])  
date_list
# Out:
# ['2023-09-01',
#  '2023-09-02',
#  '2023-09-03',
#  '2023-09-04',
#  '2023-09-05',
#  '2023-09-06',
#  '2023-09-07',
#  '2023-09-08',
#  '2023-09-09',
#  '2023-09-10',
#  '2023-09-11',
#  '2023-09-12',
#  '2023-09-13',
#  '2023-09-14',
#  '2023-09-15',
#  '2023-09-16',
#  '2023-09-17',
#  '2023-09-18',
#  '2023-09-19',
#  '2023-09-20',
#  '2023-09-21',
#  '2023-09-22',
#  '2023-09-23',
#  '2023-09-24',
#  '2023-09-25',
#  '2023-09-26',
#  '2023-09-27',
#  '2023-09-28',
#  '2023-09-29',
#  '2023-09-30']

# %%
df = pd.DataFrame(data = data)
pivot_df = df.pivot(index='Medicine', columns='Date', values='Quantity')

# Set the 'Medicine' column as the index
df.set_index('Medicine', inplace=True)

# Choose the row you want to plot, e.g., 'Metformin'
row_to_plot = df.loc[medicine_names[6]]

# Plot the selected row
ax = row_to_plot.plot(kind='bar')

# Set labels for the x and y-axis
plt.xlabel('Date')
plt.ylabel('Quantity')

# Set the title of the plot
plt.title('Quantity Over Time')

ax.set_xticks(range(len(row_to_plot.Date)))
ax.set_xticklabels(row_to_plot.Date, ha='right')

# Show the plot
plt.show()

# %%
from scipy.stats import linregress
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[197], line 1
# ----> 1 from scipy.stats import linregress
#
# ModuleNotFoundError: No module named 'scipy'

# %%
# Create fake today's medicine inventory information of pharmacies
medicine_names = ["Metformin", "Metoprolol", "Fluticasone", "Ipratropium", "Methotrexate", "Raloxifene", "Atorvastatin", "Carbamazepine", "Azathioprine"]
